# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel4ngel/AMP-Tech/blob/master/emisiones_CO2_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Autor: Joel Taquía

#Llamo las librias que usaré
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
#=====================================================
#1. Cargo la data que previamente lo subi a mi DRIVE
ruta= '//content//drive//My Drive//Colab Notebooks//emision_co2.csv'

df = pd.read_csv(ruta,sep=';',)

#Elimino la ultima columna,pues la ultima columna del csv se guardo con ';'
df=df.drop(df.columns[-1], axis='columns')
df
# Out:
#                     pais codigo  construccion  ...  fugas  energia     nivel
# 0                  China    CHN         457.2  ...   0.00   4455.4  muy alto
# 1          United States    USA         460.6  ...  11.93   2360.2  muy alto
# 2    European Union (27)     UE         486.9  ...   1.86   1289.8  muy alto
# 3                  India    IND          96.6  ...   1.91    995.1  muy alto
# 4                 Russia    RUS         122.4  ...  32.66   1007.7  muy alto
# 5                  Japan    JPN         131.0  ...   0.00    628.3  muy alto
# 6                Germany    DEU         138.0  ...   1.59    364.6  muy alto
# 7            South Korea    KOR          51.3  ...   0.00    350.7      alto
# 8                   Iran    IRN         113.5  ...  32.22    177.7      alto
# 9                 Canada    CAN          74.2  ...   3.34    209.0      alto
# 10          Saudi Arabia    SAU           4.6  ...   0.00    222.4      alto
# 11                Mexico    MEX          23.7  ...   2.84    212.4      alto
# 12        United Kingdom    GBR          90.5  ...   1.91    211.5      alto
# 13                Brazil    BRA          20.0  ...   2.68     81.7      alto
# 14             Indonesia    IDN          21.6  ...  12.36    168.8      alto
# 15          South Africa    ZAF          25.0  ...   0.00    281.6      alto
# 16             Australia    AUS          13.0  ...   0.49    235.4      alto
# 17                 Italy    ITA          69.5  ...   0.00    144.0      alto
# 18                Turkey    TUR          55.1  ...   0.00    126.9      alto
# 19                France    FRA          77.0  ...   0.00     63.8      alto
# 20                Poland    POL          47.6  ...   0.03    164.5      alto
# 21               Ukraine    UKR          37.3  ...   0.00    140.2      alto
# 22                 Spain    ESP          24.8  ...   0.00    109.3      alto
# 23              Thailand    THA           9.5  ...   0.00    106.1      alto
# 24            Kazakhstan    KAZ          16.6  ...   4.92    131.2      alto
# 25                 Egypt    EGY          15.3  ...   0.71     87.7      alto
# 26              Malaysia    MYS           4.4  ...   2.41    108.9      alto
# 27             Argentina    ARG          26.5  ...   1.70     71.6      alto
# 28             Venezuela    VEN           6.4  ...  19.59     58.8      alto
# 29  United Arab Emirates    ARE           0.5  ...   1.86     67.9      alto
# 30           Netherlands    NLD          28.2  ...   0.05     64.9      alto
# 31                  Iraq    IRQ          12.1  ...  21.83     63.4      alto
# 32               Vietnam    VNM           9.9  ...   1.15     41.4      alto
# 33              Pakistan    PAK          19.4  ...   0.16     41.9      alto
# 34               Algeria    DZA          16.8  ...   6.46     43.3      alto
# 35            Uzbekistan    UZB          40.5  ...   0.00     40.6      alto
# 36        Czech Republic    CZE          11.8  ...   0.00     63.7      alto
# 37               Belgium    BEL          22.9  ...   0.00     25.5     medio
# 38               Nigeria    NGA           1.6  ...  24.02     23.6     medio
# 39           Philippines    PHL           5.3  ...   0.44     38.5     medio
# 40               Romania    ROU           8.6  ...   0.00     39.7     medio
# 41                Greece    GRC           7.5  ...   0.00     45.8     medio
# 42                 Chile    CHL           5.4  ...   0.11     37.0     medio
# 43                Kuwait    KWT           0.6  ...   0.44     51.0     medio
# 44                Israel    ISR           2.7  ...   0.05     51.0     medio
# 45                 Qatar    QAT           0.3  ...   1.37     46.9     medio
# 46              Colombia    COL           5.3  ...   1.26     15.1     medio
# 47          Turkmenistan    TKM          16.7  ...   1.31     23.3     medio
# 48               Austria    AUT           8.1  ...   0.00     22.4     medio
# 49            Bangladesh    BGD           6.7  ...   0.00     28.3     medio
# 50               Morocco    MAR           6.0  ...   0.00     20.5     medio
# 51               Belarus    BLR           5.4  ...   0.00     33.1     medio
# 52                  Oman    OMN           0.3  ...   2.30     21.4     medio
# 53                 Libya    LBY           2.1  ...   7.17     24.1     medio
# 54               Finland    FIN           2.4  ...   0.00     24.6     medio
# 55              Portugal    PRT           2.9  ...   0.00     20.3     medio
# 56                  Peru    PER           2.7  ...   0.33     15.2     medio
# 57             Singapore    SGP           0.6  ...   0.00     27.5     medio
# 58                Serbia    SRB           2.8  ...   0.00     31.4     medio
# 59              Bulgaria    BGR           1.4  ...   0.00     31.0     medio
#
# [60 rows x 10 columns]

# %%
#2.	Selecciono las variables dependientes e independientes que usaré en el PCA

#Variables dependientes,la submatriz X contiene los valores de los 7 sectores.
X = df.iloc[:,2:9]

#Variables independientes
y = df.iloc[:,-1]#.values
# El vector y contiene los categoricos de la ultima variable

# %%
X.head() #variable dependiente 5 primeros datos.
# Out:
#    construccion  industrias  ...  fugas  energia
# 0         457.2      714.80  ...   0.00   4455.4
# 1         460.6       35.27  ...  11.93   2360.2
# 2         486.9       53.74  ...   1.86   1289.8
# 3          96.6      101.40  ...   1.91    995.1
# 4         122.4       26.25  ...  32.66   1007.7
#
# [5 rows x 7 columns]

# %%
y.head() #variable independiente 5 primeros datos.
# Out:
# 0    muy alto
# 1    muy alto
# 2    muy alto
# 3    muy alto
# 4    muy alto
# Name: nivel, dtype: object

# %%
#3. Normalizo las variables
#===========================
from sklearn.preprocessing import StandardScaler
Z = StandardScaler().fit_transform(X)

# %%
# Calculo la matriz de varianzas y covarianza
cov_mat=np.cov(Z.T)
pd.DataFrame(cov_mat)
# Out:
#           0         1         2         3         4         5         6
# 0  1.016949  0.599876  0.796729  0.907334  0.680806  0.130058  0.871780
# 1  0.599876  1.016949  0.952578  0.400725  1.008847 -0.033699  0.890897
# 2  0.796729  0.952578  1.016949  0.616455  0.975546 -0.006527  0.958993
# 3  0.907334  0.400725  0.616455  1.016949  0.498685  0.170850  0.775867
# 4  0.680806  1.008847  0.975546  0.498685  1.016949 -0.015654  0.939005
# 5  0.130058 -0.033699 -0.006527  0.170850 -0.015654  1.016949  0.093534
# 6  0.871780  0.890897  0.958993  0.775867  0.939005  0.093534  1.016949

# %%
#4.Obtengo los autovectores y autovalores de la matriz de covarianza
#====================================================================
eig_vals, eig_vecs = np.linalg.eig(cov_mat)

# %%
#AUTOVALORES ya ordenados
pd.DataFrame(eig_vals)
# Out:
#           0
# 0  5.014361
# 1  1.180004
# 2  0.784299
# 3  0.092163
# 4  0.031250
# 5  0.014836
# 6  0.001730

# %%
#AUTOVECTORES(filas)
pd.DataFrame(eig_vecs)
# Out:
#           0         1         2         3         4         5         6
# 0  0.394220  0.272163 -0.354254 -0.723022 -0.336277  0.090464  0.031546
# 1  0.402633 -0.301203  0.342116  0.100254 -0.174592  0.419253  0.643283
# 2  0.436498 -0.144816  0.103748 -0.271321  0.824249 -0.154472 -0.029521
# 3  0.337705  0.419765 -0.513900  0.542596  0.200980  0.332747  0.011602
# 4  0.422016 -0.237382  0.258454  0.122625 -0.239177  0.241108 -0.753908
# 5  0.031933  0.762260  0.644828 -0.023980  0.031801  0.022049 -0.008015
# 6  0.445852  0.025290  0.001133  0.289052 -0.280072 -0.789203  0.125472

# %%
#Grafico de sedimentacion
plt.plot(eig_vals,'go-')
plt.ylabel('autovalor')
plt.xlabel('número de componente')
plt.title('Gráfico de sedimentacion')
plt.grid()
plt.show()

# %%
#Grafico de varianza simples y acumuladas

# A partir de los autovalores, calculamos la varianza explicada
tot = sum(eig_vals)

#varianza porcentual para cada autovalor
var_exp = [(i/tot)*100 for i in eig_vals] #sorted(eig_vals, reverse=True)

#Hago una suma acumulada
cum_var_exp = np.cumsum(var_exp)

# Representamos en un diagrama de barras la varianza explicada por cada autovalor y la acumulada
with plt.style.context('seaborn-pastel'):
    plt.figure(figsize=(7,5))

    plt.bar(range(7), var_exp, align='center',label='var.explicada', color='b')
    plt.step(range(7), cum_var_exp, where='mid', linestyle='--', label='var.explicada acumulada',color='r')
    plt.ylabel('varianza Explicada (%)')
    plt.xlabel('componente')
    plt.legend(loc='center')
    plt.title('Porcentaje de variacion explicado por cada componente')
    plt.grid()

# %%
#Resumen de las varianzas
data={'Yi':[i for i in range(1,8)],'autovalores':eig_vals,'vza.explic(%)':var_exp,'vza.explic.acum.(%)':cum_var_exp}

resumen=pd.DataFrame(data)
blankIndex=[''] * len(resumen)
resumen.index=blankIndex
resumen
# Out:
#   Yi  autovalores  vza.explic(%)  vza.explic.acum.(%)
#    1     5.014361      70.439829            70.439829
#    2     1.180004      16.576252            87.016082
#    3     0.784299      11.017536            98.033618
#    4     0.092163       1.294668            99.328286
#    5     0.031250       0.438992            99.767278
#    6     0.014836       0.208417            99.975695
#    7     0.001730       0.024305           100.000000

# %% [markdown]
# # **PROYECCIONES**
# **i. TOMANDO 2 DIMENSIONES** : 87% de variabilidad

# %%
#5.Selecciono los 2 autovectores más grandes correspondientes a sus CP

# El 1er y 2do autovalor los coloco en una matriz Base: B
B = np.array([eig_vecs[0],eig_vecs[1]])

# Las nuevas variables obtenidas de dimension: 60x2
Y = Z.dot(B.T)

print('Matriz Base:')
pd.DataFrame(B.T)
# Out:
# Matriz Base:
#           0         1
# 0  0.394220  0.402633
# 1  0.272163 -0.301203
# 2 -0.354254  0.342116
# 3 -0.723022  0.100254
# 4 -0.336277 -0.174592
# 5  0.090464  0.419253
# 6  0.031546  0.643283

# %%
#Componentes principales y su cetegoria
Y_new=pd.DataFrame(Y, columns=['pc1', 'pc2'])

#Y concateno con sus categorías iniciales
W=pd.concat([Y_new,y], axis=1)
W.head()
# Out:
#         pc1       pc2     nivel
# 0 -2.907810  4.479806  muy alto
# 1 -3.529065  5.057005  muy alto
# 2 -1.130707  3.382422  muy alto
# 3 -0.832115  1.072419  muy alto
# 4  0.178653  2.724244  muy alto

# %%
#Proyeccion reducida a 2D con sus categorias
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(1,1,1)

targets = W.nivel.unique()#['muy alto', 'alto', 'medio']
colors = ['r', 'g', 'cyan']
for target, color in zip(targets,colors):
    indice = W['nivel'] == target
    ax.scatter(W.loc[indice, 'pc1'], W.loc[indice,'pc2'], c = color)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_title('2 componentes PCA', fontsize = 20)
ax.legend(targets)
ax.grid()

# %% [markdown]
# **ii. TOMANDO 3 DIMENSIONES** : 98% de variabilidad

# %%
# Selecciono los 3 autovectores más grandes correspondientes a sus CP
# El 1er y 2do autovalor los coloco en una matriz Base: B
B2 = np.array([eig_vecs[0],eig_vecs[1],eig_vecs[2]])

# Las nuevas variables obtenidas de dimension: 60x3
Y2 = Z.dot(B2.T)

print('Matriz Base:')
pd.DataFrame(B2.T)
# Out:
# Matriz Base:
#           0         1         2
# 0  0.394220  0.402633  0.436498
# 1  0.272163 -0.301203 -0.144816
# 2 -0.354254  0.342116  0.103748
# 3 -0.723022  0.100254 -0.271321
# 4 -0.336277 -0.174592  0.824249
# 5  0.090464  0.419253 -0.154472
# 6  0.031546  0.643283 -0.029521

# %%
#Componentes principales y su cetegoria
Y2_new=pd.DataFrame(Y2, columns=['pc1', 'pc2','pc3'])
W2=pd.concat([Y2_new,y], axis=1)
W2.head()
# Out:
#         pc1       pc2       pc3     nivel
# 0 -2.907810  4.479806  6.720545  muy alto
# 1 -3.529065  5.057005  0.585987  muy alto
# 2 -1.130707  3.382422  1.840807  muy alto
# 3 -0.832115  1.072419  0.818252  muy alto
# 4  0.178653  2.724244 -0.340709  muy alto

# %%
#Proyeccion reducida a 3D con sus categorias

fig = plt.figure(figsize =(15,9))
ax = fig.add_subplot(111, projection='3d')

targets = W2.nivel.unique()#['muy alto', 'alto', 'medio']
colors = ['r', 'g', 'cyan']
for target, color in zip(targets,colors):
    indice = W2['nivel'] == target
    ax.scatter(W2.loc[indice, 'pc1'], W2.loc[indice,'pc2'],W2.loc[indice,'pc3'], c = color)


for pais,x,y,z in zip(df['codigo'],W2['pc1'],W2['pc2'],W2['pc3']):
  ax.text(x, y, z,pais, size=8, zorder=1)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('3 componentes PCA', fontsize =12)
ax.legend(targets)
ax.grid()

# %% [markdown]
# **HACIENDO UN ZOOM**

# %%
#6. Proyeccion reducida a 2D con sus categorias
#import matplotlib.pyplot as plt
#import plottools
fig = plt.figure(figsize = (14,8))
ax = fig.add_subplot(111)

#fig, ax = plt.subplots(1, figsize=(16,10))


targets = W.nivel.unique()#['muy alto', 'alto', 'medio']
colors = ['r', 'g', 'cyan']

for target, color in zip(targets,colors):
  indice = W['nivel'] == target
  ax.scatter(W.loc[indice, 'pc1'], W.loc[indice,'pc2'], c = color)

for pais,x,y, in zip(df['codigo'],W['pc1'],W['pc2']):
  ax.annotate(pais, xy=(x,y), xytext=(x,y+0.2), textcoords = "offset points", horizontalalignment="right",size=8)


ax.set_xlabel('PC1',size=12,fontweight ='bold')
ax.set_ylabel('PC2',size=12,fontweight ='bold')
ax.set_title('2 componentes PCA', fontsize = 20)
ax.legend(targets)
ax.grid()

axins = zoomed_inset_axes(ax,15, loc='lower left')#,bbox_to_anchor=(2.5,2))
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="m")

for target, color,pais,x,y in zip(targets,colors,df['codigo'],W2['pc1'],W2['pc2']):
  indice = W['nivel'] == target
  axins.scatter(W.loc[indice, 'pc1'], W.loc[indice,'pc2'], c = color)
  #axins.text(x, y,pais, size=8)

axins.set_xlim(0.125, 0.250)
axins.set_ylim(-0.7,-0.5)
axins.grid()
plt.show()
